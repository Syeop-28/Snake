# %% [markdown]
# # Python 101

# %% [markdown]
# <img src="img/snake1.jpg" width=700>

# %% [markdown]
# <table style="width:50%">
#   <tr>
#     <th>Teclado rápido</th>
#     <th>Función</th>
#    </tr>
#   <tr>
#     <td>Enter</td>
#     <td>Activa el modo de edición de la celda</td>
#    </tr>
#    <tr>
#     <td>Ctrl + a</td>
#     <td>Selecciona todas las celdas del cuaderno</td>
#    </tr>
#    <tr>
#     <td>Ctrl + c</td>
#     <td>Copia la(s) celda(s) del cuaderno</td>
#    </tr>
#    <tr>
#     <td>Ctrl + v</td>
#     <td>Pega la(s) celda(s) del cuaderno</td>
#    </tr>
#    <tr>
#     <td>Ctrl + z</td>
#     <td>Con el modo de edición activado, <br>
#     elimina la última acción realizada</td>
#    </tr>
#    <tr>
#     <td><strong>Shift + Enter</strong></td>
#     <td>Ejecuta la celda seleccionada</td>
#    </tr>
#    <tr>
#     <td>Alt + Enter</td>
#     <td>Ejecuta la celda seleccionada, <br>
#     Genera una nueva celda de código.</td>
#    </tr>
#    <tr>
#     <td>Shift + Tabulador</td>
#     <td>Dentro de una función, <br>
#     despliega la ayuda de la función.</td>
#    </tr>
#    <tr>
#     <td>Esc + d + d</td>
#     <td>Elimina la celda seleccionada</td>
#    </tr>
#    <tr>
#     <td>Esc + m</td>
#     <td>Convierte la celda seleccionada a Markdown</td>
#    </tr>
#    <tr>
#     <td>Esc + y</td>
#     <td>Convierte la celda seleccionada a código</td>
#    </tr>
# </table>

# %%
from IPython.display import YouTubeVideo

url="lc5JJTQa4r8"
YouTubeVideo(id=url,width=500,height=300)

# %% [markdown]
# # Programación Orientada a Objetos

# %% [markdown]
# <img src="img/poo.jpg">

# %% [markdown]
# Paradigma de programación que utiliza a los **objetos como elementos fundamentales** en la construcción de la solución a un problema informático.
#
# Un **paradigma de programación** es un estilo de *desarrollo de programas*. Es decir, un modelo para resolver problemas computacionales.
#
# Para entender POO, es necesario entender los siguientes conceptos:
#
#
# * **Objetos**
#                     Ente abstracto que contiene métodos y atributos.
#
# * **Clases**
#                     Es la descripción general de un objeto.
#
# * **Herencia**
#                     Mecanismo para compartir automáticamente métodos y datos entre clases, subclases y objetos.
#
# * **Abstracción**
#                     Captar las características escenciales de un objeto.
#
# * **Encapsulamiento**
#                     Ocultamiento del estado de los datos dentro de un objeto.
#
# * **Polimorfismo**
#                     Capacidad de mandar mensajes sintácticamente iguales a objetos diferentes.
#
# * **Envío de mensajes**
#                     Invocación de los métodos de los objetos

# %% [markdown]
# # Comandos más útiles

# %% [markdown]
# <table style="width:70%">
#   <tr>
#     <th>Comando</th>
#     <th>Sintaxis</th>
#     <th>Función</th>
#   </tr>
#   <tr>
#     <td><strong>print</strong></td>
#     <td>print(objeto) / print("___")</td>
#     <td>Imprimirá en pantalla el objeto/mensaje solicitado</td>
#   </tr>
#   <tr>
#     <td><strong>input</strong></td>
#     <td>input("Mensaje opcional")</td>
#     <td>Hará una solicitud de información al usuario. De forma opcional se puede indicar un mensaje</td>
#   </tr>
#   <tr>
#     <td><strong>help</strong></td>
#     <td>help(objeto)</td>
#     <td>Proporciona información relevante con respecto al objeto solicitado</td>
#   </tr>
#   <tr>
#     <td><strong>dir</strong></td>
#     <td>dir(objeto)</td>
#     <td>Proporciona métodos y atributos con respecto al objeto solicitado</td>
#   </tr>
#   <tr>
#     <td><strong>len</strong></td>
#     <td>len(objeto)</td>
#     <td>Indica la longitud del objeto solicitado</td>
#   </tr>
#   <tr>
#     <td><strong>type</strong></td>
#     <td>type(objeto)</td>
#     <td>Proporciona el tipo del objeto solicitado</td>
#   </tr>
# </table>
